# %% [markdown]
# # President's Night 2016
# On this webpage you can follow Trump and Hillary's chances of winning the presidency through election night. Using predictions from [FiveThirtyEight](http://www.fivethirtyeight.com) as input, this page will update the win probabilities automatically as I submit incoming results from the vote counting.

# %%
# %matplotlib inline
# %run "Apps/PlainText 2/election2016.py"
(df, dfbetas, dfstates, exitpolls) = read_data()
exitpolls.head()
# Out:
# Last submitted results (updated at 17:26:06 11/07/16):
#       Percentage in  Hillary  Trump
# Code
# AR              0.3     0.46   0.47
# FL              0.2     0.48   0.44
# AR              0.8     0.45   0.48

# %% [markdown]
# ### Doing 10,000 simulations

# %%
(agg_bysim, agg_bystate) = election2016(df, dfbetas, dfstates, 10000)

# %% [markdown]
# ### Probability of winning throughout election night

# %%
plot_winprobs_time()

# %% [markdown]
# ### Hillary's win probabilities per state

# %%
plot_map(agg_bystate)

# %% [markdown]
# ### Histogram of simulated electoral votes per candidate

# %%
win_histogram(agg_bysim)

# %% [markdown]
# ### Predicted total electoral votes throughout election night

# %%
plot_elecvotes_time()

# %% [markdown]
# ### Win probabilities per state

# %%
plot_states(agg_bystate)
